# %%
import pandas as pd
data = pd.read_csv("./test.csv",encoding="ANSI")
data.head(25)
# Out:
#                  600004              600004.1               600004.2  \
# 0                  营业收入                  营业利润                   利润总额
# 1    0.4273904656930284  -0.04193205944798301  -0.050519527051236114
# 2    0.5146076794657763    0.1868962620747585    0.18187592631801822
# 3    1.0219409282700422     1.579631635969664     1.5682436106579662
# 4   -0.7732057416267942   0.05606407322654462    0.23921832884097036
# 5   0.38925817601701673  -0.22791519434628976   -0.29867674858223064
# 6    0.5977060322854716    1.4049288294030169     1.5893294175232502
# 7     0.791476407914764    -1.538558352402746     -1.460394366197183
# 8   -0.8405146255613545   -0.8769014084507042    -0.8757002801120448
# 9    0.3471223021582734     0.603794894962729     0.5834996673320024
# 10   0.5127380657927282    0.3978528575939373     0.3890942698706102
# 11   1.0124440019910403     0.800966733011089      0.831311706629055
# 12  -0.7406738092164709   -0.7698298429319371    -0.7695058517555267
# ...

# %%
data2 = pd.read_excel("./510家公司财务数据数据33.xlsx")
data2.head()
# Out:
#    公司名    公司代码   利润表       2021-12-31        Unnamed: 4  2021-12-31 00:00:00  \
# 0  1.0  600004  营业收入  51.80*100000000  =51.80*100000000         5.180000e+09
# 1  NaN  600004  营业利润       -541500000       =-541500000        -5.415000e+08
# 2  NaN  600004  利润总额       -530000000       =-530000000        -5.300000e+08
# 3  NaN  600004   净利润       -385400000       =-385400000        -3.854000e+08
# 4  2.0  600006  营业收入  155.5*100000000  =155.5*100000000         1.555000e+10
#
#    2021.12增长率       2021-09-30        Unnamed: 8  2021-09-01 00:00:00  ...  \
# 0    0.427390  36.29*100000000  =36.29*100000000         3.629000e+09  ...
# 1   -0.041932       -565200000       =-565200000        -5.652000e+08  ...
# 2   -0.050520       -558200000       =-558200000        -5.582000e+08  ...
# 3   -0.200747       -482200000       =-482200000        -4.822000e+08  ...
# 4    0.274590  122.0*100000000  =122.0*100000000         1.220000e+10  ...
#
# ...

# %%
list_id=data2.loc[:,['公司代码']]
# df=data_test.loc[0:3,:]

# %%
print(type(list_id))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
data_array = np.array(list_id)
# 然后转化为list形式
data_list =data_array.tolist()

# %%
com_id=[]
for i in data_list:
    for j in i:
        if j not in com_id:
            com_id.append(j)

# %%
print(com_id)
# Out:
# [600004, 600006, 600007, 600008, 600011, 600012, 600016, 600017, 600018, 600022, 600026, 600027, 600028, 600029, 600030, 600033, 600036, 600038, 600039, 600050, 600051, 600058, 600061, 600062, 600063, 600066, 600067, 600071, 600073, 600076, 600081, 600085, 600089, 600096, 600097, 600098, 600101, 600103, 600113, 600115, 600118, 600125, 600126, 600127, 600129, 600130, 600132, 600135, 600138, 600141, 600151, 600168, 600171, 600173, 600176, 600178, 600183, 600184, 600188, 600192, 600196, 600207, 600210, 600211, 600212, 600218, 600219, 600231, 600232, 600235, 600237, 600249, 600251, 600255, 600258, 600267, 600268, 600269, 600271, 600272, 600273, 600279, 600282, 600284, 600292, 600298, 600299, 600300, 600306, 600308, 600309, 600310, 600313, 600315, 600316, 600318, 600319, 600320, 600322, 600323, 600325, 600329, 600330, 600332, 600335, 600346, 600350, 600353, 600354, 600355, 600358, 600361, 600362, 600366, 600368, 600370, 600372, 600375, 600377, 600379, 600380, 600386, 600391, 600396, 60040
# ...

# %%
data_list = pd.read_excel("./com_id.xlsx")
data_list.head(30)
# Out:
#       600004  600004.1   600004.2  600004.3
# 0   0.427390 -0.041932  -0.050520 -0.200747
# 1   0.514608  0.186896   0.181876  0.208521
# 2   1.021941  1.579632   1.568244  1.614679
# 3  -0.773206  0.056064   0.239218 -0.341958
# 4   0.389258 -0.227915  -0.298677 -0.187741
# 5   0.597706  1.404929   1.589329  0.691351
# 6   0.791476 -1.538558  -1.460394  1.658268
# 7  -0.840515 -0.876901  -0.875700 -1.056145
# 8   0.347122  0.603795   0.583500  0.644134
# 9   0.512738  0.397853   0.389094  0.390259
# 10  1.012444  0.800967   0.831312  0.866465
# 11 -0.740674 -0.769830  -0.769506 -0.771859
# 12  0.334999  0.225341   0.227454  0.236696
# 13  0.559527  0.310012   0.312042  0.312657
# 14  1.158353  0.600101   0.601274  0.640238
# 15  0.274590 -0.266577  -0.305370 -0.264293
# 16  0.379622  0.077636   0.077736  0.017829
# 17  1.230827  0.874903   0.810325  0.877851
# 18 -0.711289 -0.568405  -0.485033 -0.508410
# 19  0.358061  0.208904   0.249508  0.116519
# ...

# %%
list_com=[]
for i in com_id:
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
    list_com.append(i)
print(list_com)
# Out:
# [600004, 600004, 600004, 600004, 600004, 600004, 600004, 600004, 600004, 600004, 600004, 600004, 600004, 600004, 600004, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600006, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600007, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600008, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600011, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600012, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600016, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600017, 600018, 600018, 600018, 600018, 60001
# ...

# %%
data_list.insert(loc=0, column='公司代码', value=list_com)

# %%
data_list.head(50)
# Out:
#       公司代码    600004  600004.1   600004.2  600004.3
# 0   600004  0.427390 -0.041932  -0.050520 -0.200747
# 1   600004  0.514608  0.186896   0.181876  0.208521
# 2   600004  1.021941  1.579632   1.568244  1.614679
# 3   600004 -0.773206  0.056064   0.239218 -0.341958
# 4   600004  0.389258 -0.227915  -0.298677 -0.187741
# 5   600004  0.597706  1.404929   1.589329  0.691351
# 6   600004  0.791476 -1.538558  -1.460394  1.658268
# 7   600004 -0.840515 -0.876901  -0.875700 -1.056145
# 8   600004  0.347122  0.603795   0.583500  0.644134
# 9   600004  0.512738  0.397853   0.389094  0.390259
# 10  600004  1.012444  0.800967   0.831312  0.866465
# 11  600004 -0.740674 -0.769830  -0.769506 -0.771859
# 12  600004  0.334999  0.225341   0.227454  0.236696
# 13  600004  0.559527  0.310012   0.312042  0.312657
# 14  600004  1.158353  0.600101   0.601274  0.640238
# 15  600006  0.274590 -0.266577  -0.305370 -0.264293
# 16  600006  0.379622  0.077636   0.077736  0.017829
# ...

# %%
gongsi = pd.read_excel("./test3.xlsx")
gongsi.head(30)
# Out:
#           公司代码    600004  600004.1   600004.2  600004.3
# 0   2021.12增长率  0.427390 -0.041932  -0.050520 -0.200747
# 1   2021.09增长率  0.514608  0.186896   0.181876  0.208521
# 2   2021.06增长率  1.021941  1.579632   1.568244  1.614679
# 3   2021.03增长率 -0.773206  0.056064   0.239218 -0.341958
# 4   2020.12增长率  0.389258 -0.227915  -0.298677 -0.187741
# 5   2020.09增长率  0.597706  1.404929   1.589329  0.691351
# 6   2020.06增长率  0.791476 -1.538558  -1.460394  1.658268
# 7   2020.03增长率 -0.840515 -0.876901  -0.875700 -1.056145
# 8   2019.12增长率  0.347122  0.603795   0.583500  0.644134
# 9   2019.09增长率  0.512738  0.397853   0.389094  0.390259
# 10  2019.06增长率  1.012444  0.800967   0.831312  0.866465
# 11  2019.03增长率 -0.740674 -0.769830  -0.769506 -0.771859
# 12  2018.12增长率  0.334999  0.225341   0.227454  0.236696
# 13  2018.09增长率  0.559527  0.310012   0.312042  0.312657
# 14  2018.06增长率  1.158353  0.600101   0.601274  0.640238
# 15  2021.12增长率  0.274590 -0.266577  -0.305370 -0.264293
# ...

# %%
gongsi.insert(loc=0, column='公司id', value=list_com)

# %%
gongsi.head(50)
# Out:
#       公司id        公司代码    600004  600004.1   600004.2  600004.3
# 0   600004  2021.12增长率  0.427390 -0.041932  -0.050520 -0.200747
# 1   600004  2021.09增长率  0.514608  0.186896   0.181876  0.208521
# 2   600004  2021.06增长率  1.021941  1.579632   1.568244  1.614679
# 3   600004  2021.03增长率 -0.773206  0.056064   0.239218 -0.341958
# 4   600004  2020.12增长率  0.389258 -0.227915  -0.298677 -0.187741
# 5   600004  2020.09增长率  0.597706  1.404929   1.589329  0.691351
# 6   600004  2020.06增长率  0.791476 -1.538558  -1.460394  1.658268
# 7   600004  2020.03增长率 -0.840515 -0.876901  -0.875700 -1.056145
# 8   600004  2019.12增长率  0.347122  0.603795   0.583500  0.644134
# 9   600004  2019.09增长率  0.512738  0.397853   0.389094  0.390259
# 10  600004  2019.06增长率  1.012444  0.800967   0.831312  0.866465
# 11  600004  2019.03增长率 -0.740674 -0.769830  -0.769506 -0.771859
# 12  600004  2018.12增长率  0.334999  0.225341   0.227454  0.236696
# 13  600004  2018.09增长率  0.559527  0.310012   0.312042  0.312657
# ...

# %%
gongsi.to_excel('result_com.xlsx', sheet_name='Sheet1')
