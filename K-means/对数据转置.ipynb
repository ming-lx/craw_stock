# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
data = pd.read_excel("./510家公司财务数据数据33.xlsx")
data.head()
# Out:
#    公司名    公司代码   利润表       2021-12-31        Unnamed: 4  2021-12-31 00:00:00  \
# 0  1.0  600004  营业收入  51.80*100000000  =51.80*100000000         5.180000e+09
# 1  NaN  600004  营业利润       -541500000       =-541500000        -5.415000e+08
# 2  NaN  600004  利润总额       -530000000       =-530000000        -5.300000e+08
# 3  NaN  600004   净利润       -385400000       =-385400000        -3.854000e+08
# 4  2.0  600006  营业收入  155.5*100000000  =155.5*100000000         1.555000e+10
#
#    2021.12增长率       2021-09-30        Unnamed: 8  2021-09-01 00:00:00  ...  \
# 0    0.427390  36.29*100000000  =36.29*100000000         3.629000e+09  ...
# 1   -0.041932       -565200000       =-565200000        -5.652000e+08  ...
# 2   -0.050520       -558200000       =-558200000        -5.582000e+08  ...
# 3   -0.200747       -482200000       =-482200000        -4.822000e+08  ...
# 4    0.274590  122.0*100000000  =122.0*100000000         1.220000e+10  ...
#
# ...

# %%
data_test=data.loc[:, ['公司代码', '利润表','2021.12增长率','2021.09增长率','2021.06增长率','2021.03增长率','2020.12增长率','2020.09增长率','2020.06增长率','2020.03增长率','2019.12增长率','2019.09增长率','2019.06增长率','2019.03增长率','2018.12增长率','2018.09增长率','2018.06增长率']]

# %%
data_test.head(10)
# Out:
#      公司代码   利润表  2021.12增长率  2021.09增长率  2021.06增长率  2021.03增长率  2020.12增长率  \
# 0  600004  营业收入    0.427390    0.514608    1.021941   -0.773206    0.389258
# 1  600004  营业利润   -0.041932    0.186896    1.579632    0.056064   -0.227915
# 2  600004  利润总额   -0.050520    0.181876    1.568244    0.239218   -0.298677
# 3  600004   净利润   -0.200747    0.208521    1.614679   -0.341958   -0.187741
# 4  600006  营业收入    0.274590    0.379622    1.230827   -0.711289    0.358061
# 5  600006  营业利润   -0.266577    0.077636    0.874903   -0.568405    0.208904
# 6  600006  利润总额   -0.305370    0.077736    0.810325   -0.485033    0.249508
# 7  600006   净利润   -0.264293    0.017829    0.877851   -0.508410    0.116519
# 8  600007  营业收入    0.346096    0.522286    1.085071   -0.729083    0.386130
# 9  600007  营业利润    0.317568    0.520622    1.148534   -0.710146    0.358837
#
#    2020.09增长率  2020.06增长率  2020.03增长率  2019.12增长率  2019.09增长率  2019.06增长率  \
# ...

# %%
df=data_test.loc[0:3,:]
df2=data_test.loc[4:7,:]
df_T=df.T
df_T2=df2.T
df_T.append(df_T2)


# df_T=df.T
# for i in range(3):
#     idx=i*4
#     df=data_test.loc[idx:idx+3,:]
#     df_T=df.T
#     df_T.append(df_T)
# df_T.head()

# # data_test.loc[4:7,:]
# # 03,4,7,
# # idx,idx+3
# # data_id=data_test.loc[0:3]
# Out:
#                    0         1         2         3         4         5  \
# 公司代码          600004    600004    600004    600004       NaN       NaN
# 利润表             营业收入      营业利润      利润总额       净利润       NaN       NaN
# 2021.12增长率   0.42739 -0.041932  -0.05052 -0.200747       NaN       NaN
# 2021.09增长率  0.514608  0.186896  0.181876  0.208521       NaN       NaN
# 2021.06增长率  1.021941  1.579632  1.568244  1.614679       NaN       NaN
# 2021.03增长率 -0.773206  0.056064  0.239218 -0.341958       NaN       NaN
# 2020.12增长率  0.389258 -0.227915 -0.298677 -0.187741       NaN       NaN
# 2020.09增长率  0.597706  1.404929  1.589329  0.691351       NaN       NaN
# 2020.06增长率  0.791476 -1.538558 -1.460394  1.658268       NaN       NaN
# 2020.03增长率 -0.840515 -0.876901   -0.8757 -1.056145       NaN       NaN
# 2019.12增长率  0.347122  0.603795    0.5835  0.644134       NaN       NaN
# 2019.09增长率  0.512738  0.397853  0.389094  0.390259       NaN       NaN
# ...

# %%
df_T.head(25)
# Out:
#                    0         1         2         3
# 公司代码          600004    600004    600004    600004
# 利润表             营业收入      营业利润      利润总额       净利润
# 2021.12增长率   0.42739 -0.041932  -0.05052 -0.200747
# 2021.09增长率  0.514608  0.186896  0.181876  0.208521
# 2021.06增长率  1.021941  1.579632  1.568244  1.614679
# 2021.03增长率 -0.773206  0.056064  0.239218 -0.341958
# 2020.12增长率  0.389258 -0.227915 -0.298677 -0.187741
# 2020.09增长率  0.597706  1.404929  1.589329  0.691351
# 2020.06增长率  0.791476 -1.538558 -1.460394  1.658268
# 2020.03增长率 -0.840515 -0.876901   -0.8757 -1.056145
# 2019.12增长率  0.347122  0.603795    0.5835  0.644134
# 2019.09增长率  0.512738  0.397853  0.389094  0.390259
# 2019.06增长率  1.012444  0.800967  0.831312  0.866465
# 2019.03增长率 -0.740674  -0.76983 -0.769506 -0.771859
# 2018.12增长率  0.334999  0.225341  0.227454  0.236696
# 2018.09增长率  0.559527  0.310012  0.312042  0.312657
# 2018.06增长率  1.158353  0.600101  0.601274  0.640238

# %%
for i in range(0,510):
    idx=i*4
    print(idx)
    idx=i*4
    df=data_test.loc[idx:idx+3,:]
    df_s=df.T
    df_s.to_csv("test3.csv", mode='a', index=True, header=0)
# Out:
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48
# 52
# 56
# 60
# 64
# 68
# 72
# 76
# 80
# 84
# 88
# 92
# 96
# 100
# 104
# 108
# 112
# 116
# 120
# 124
# 128
# 132
# 136
# 140
# 144
# 148
# 152
# 156
# 160
# 164
# 168
# 172
# 176
# 180
# 184
# 188
# 192
# 196
# 200
# 204
# 208
# 212
# 216
# 220
# 224
# 228
# 232
# 236
# 240
# 244
# 248
# 252
# 256
# 260
# 264
# 268
# 272
# 276
# 280
# 284
# 288
# 292
# 296
# 300
# 304
# 308
# 312
# 316
# 320
# 324
# 328
# 332
# 336
# 340
# 344
# 348
# 352
# 356
# 360
# 364
# 368
# 372
# 376
# 380
# 384
# 388
# 392
# 396
# 400
# 404
# 408
# 412
# 416
# 420
# 424
# 428
# 432
# 436
# 440
# 444
# 448
# 452
# 456
# 460
# 464
# 468
# 472
# 476
# 480
# 484
# 488
# 492
# 496
# 500
# 504
# 508
# 512
# 516
# 520
# 524
# 528
# 532
# 536
# 540
# 544
# 548
# 552
# 556
# 560
# 564
# 568
# 572
# 576
# 580
# 584
# 588
# 592
# 596
# 600
# 604
# 608
# 612
# 616
# 620
# 624
# 628
# 632
# 636
# 640
# 644
# 648
# 652
# 656
# 660
# 664
# 668
# 672
# 676
# 680
# ...

# %%
df_T.head(30)
# Out:
#                    0         1         2         3
# 公司代码          600004    600004    600004    600004
# 利润表             营业收入      营业利润      利润总额       净利润
# 2021.12增长率   0.42739 -0.041932  -0.05052 -0.200747
# 2021.09增长率  0.514608  0.186896  0.181876  0.208521
# 2021.06增长率  1.021941  1.579632  1.568244  1.614679
# 2021.03增长率 -0.773206  0.056064  0.239218 -0.341958
# 2020.12增长率  0.389258 -0.227915 -0.298677 -0.187741
# 2020.09增长率  0.597706  1.404929  1.589329  0.691351
# 2020.06增长率  0.791476 -1.538558 -1.460394  1.658268
# 2020.03增长率 -0.840515 -0.876901   -0.8757 -1.056145
# 2019.12增长率  0.347122  0.603795    0.5835  0.644134
# 2019.09增长率  0.512738  0.397853  0.389094  0.390259
# 2019.06增长率  1.012444  0.800967  0.831312  0.866465
# 2019.03增长率 -0.740674  -0.76983 -0.769506 -0.771859
# 2018.12增长率  0.334999  0.225341  0.227454  0.236696
# 2018.09增长率  0.559527  0.310012  0.312042  0.312657
# 2018.06增长率  1.158353  0.600101  0.601274  0.640238

# %%
list1=[]
for row_index,row in data_test.iterrows():
    idx=0
    print(row[0])
    if (idx%4)==0:
        
        
#     list1.append(row[0])
#     print(list1)
# Out:
# 600004
# 600004
# 600004
# 600004
# 600006
# 600006
# 600006
# 600006
# 600007
# 600007
# 600007
# 600007
# 600008
# 600008
# 600008
# 600008
# 600011
# 600011
# 600011
# 600011
# 600012
# 600012
# 600012
# 600012
# 600016
# 600016
# 600016
# 600016
# 600017
# 600017
# 600017
# 600017
# 600018
# 600018
# 600018
# 600018
# 600022
# 600022
# 600022
# 600022
# 600026
# 600026
# 600026
# 600026
# 600027
# 600027
# 600027
# 600027
# 600028
# 600028
# 600028
# 600028
# 600029
# 600029
# 600029
# 600029
# 600030
# 600030
# 600030
# 600030
# 600033
# 600033
# 600033
# 600033
# 600036
# 600036
# 600036
# 600036
# 600038
# 600038
# 600038
# 600038
# 600039
# 600039
# 600039
# 600039
# 600050
# 600050
# 600050
# 600050
# 600051
# 600051
# 600051
# 600051
# 600058
# 600058
# 600058
# 600058
# 600061
# 600061
# 600061
# 600061
# 600062
# 600062
# 600062
# 600062
# 600063
# 600063
# 600063
# 600063
# 600066
# 600066
# 600066
# 600066
# 600067
# 600067
# 600067
# 600067
# 600071
# 600071
# 600071
# ...

# %%
data_id.head()
# Out:
#         2021.12增长率  2021.09增长率  2021.06增长率  2021.03增长率  2020.12增长率  \
# 公司代码
# 600004    0.134192    1.091901    5.784495   -0.819881   -0.325075
# 600006   -0.561650    0.552823    3.793907   -2.273138    0.932992
# 600007    1.303528    2.081222    4.531978   -2.864252    1.442687
# 600008    1.257194    1.884093   10.390201   -3.141144    2.292670
# 600011  -36.512917   -1.823683    1.764909   -1.929750   -0.801127
#
#         2020.09增长率  2020.06增长率  2020.03增长率  2019.12增长率  2019.09增长率  \
# 公司代码
# 600004    4.283315   -0.549209   -3.649261    2.178551    1.689944
# 600006    2.432299  -13.108819   -3.840461    1.380079    1.496624
# 600007    2.085054    3.907003   -3.161950    1.316684    2.046558
# 600008    3.671107   10.345839   -3.453082    2.540651    2.441294
# 600011    2.229232    5.390274   -0.879012   -1.261650    1.690603
#
#         2019.06增长率  2019.03增长率  2018.12增长率  2018.09增长率  2018.06增长率
# 公司代码
# 600004    3.511188   -3.051868    1.024491    1.494238    2.999966
# ...

# %%
for key,value in data_test.iteritems():
   print (key,value)
   print("######################")
# Out:
# 公司代码 0       600004
# 1       600004
# 2       600004
# 3       600004
# 4       600006
#          ...
# 2031    603996
# 2032    603997
# 2033    603997
# 2034    603997
# 2035    603997
# Name: 公司代码, Length: 2036, dtype: int64
# ######################
# 利润表 0       营业收入
# 1       营业利润
# 2       利润总额
# 3        净利润
# 4       营业收入
#         ...
# 2031     净利润
# 2032    营业收入
# 2033    营业利润
# 2034    利润总额
# 2035     净利润
# Name: 利润表, Length: 2036, dtype: object
# ######################
# 2021.12增长率 0       0.427390
# 1      -0.041932
# 2      -0.050520
# 3      -0.200747
# 4       0.274590
#           ...
# 2031    0.374880
# 2032    0.345324
# 2033   -0.109953
# 2034   -0.168887
# 2035   -0.286848
# Name: 2021.12增长率, Length: 2036, dtype: float64
# ######################
# 2021.09增长率 0       0.514608
# 1       0.186896
# 2       0.181876
# 3       0.208521
# 4       0.379622
#           ...
# 2031    0.684296
# 2032    0.433975
# 2033   -0.194713
# 2034   -0.138148
# 2035   -0.147826
# ...

# %%
for row_index,row in data_test.iterrows():
    print (row[0])
# Out:
# 600004
# 600004
# 600004
# 600004
# 600006
# 600006
# 600006
# 600006
# 600007
# 600007
# 600007
# 600007
# 600008
# 600008
# 600008
# 600008
# 600011
# 600011
# 600011
# 600011
# 600012
# 600012
# 600012
# 600012
# 600016
# 600016
# 600016
# 600016
# 600017
# 600017
# 600017
# 600017
# 600018
# 600018
# 600018
# 600018
# 600022
# 600022
# 600022
# 600022
# 600026
# 600026
# 600026
# 600026
# 600027
# 600027
# 600027
# 600027
# 600028
# 600028
# 600028
# 600028
# 600029
# 600029
# 600029
# 600029
# 600030
# 600030
# 600030
# 600030
# 600033
# 600033
# 600033
# 600033
# 600036
# 600036
# 600036
# 600036
# 600038
# 600038
# 600038
# 600038
# 600039
# 600039
# 600039
# 600039
# 600050
# 600050
# 600050
# 600050
# 600051
# 600051
# 600051
# 600051
# 600058
# 600058
# 600058
# 600058
# 600061
# 600061
# 600061
# 600061
# 600062
# 600062
# 600062
# 600062
# 600063
# 600063
# 600063
# 600063
# 600066
# 600066
# 600066
# 600066
# 600067
# 600067
# 600067
# 600067
# 600071
# 600071
# 600071
# ...

# %%
data_grou=data.groupby('公司代码')

# %%
data_grou.head()
# Out:
#       Unnamed: 0    公司代码   利润表       2021-12-31        Unnamed: 4  \
# 0            1.0  600004  营业收入  51.80*100000000  =51.80*100000000
# 1            NaN  600004  营业利润       -541500000       =-541500000
# 2            NaN  600004  利润总额       -530000000       =-530000000
# 3            NaN  600004   净利润       -385400000       =-385400000
# 4            2.0  600006  营业收入  155.5*100000000  =155.5*100000000
# ...          ...     ...   ...              ...               ...
# 2031         NaN  603996   净利润     -429100000.0       =-429100000
# 2032       510.0  603997  营业收入  168.3*100000000  =168.3*100000000
# 2033         NaN  603997  营业利润  1.708*100000000  =1.708*100000000
# 2034         NaN  603997  利润总额  1.934*100000000  =1.934*100000000
# 2035         NaN  603997   净利润  1.258*100000000  =1.258*100000000
#
#       2021-12-31 00:00:00  2021.12增长率       2021-09-30        Unnamed: 8  \
# 0            5.180000e+09    0.427390  36.29*100000000  =36.29*100000000
# ...

# %%
import numpy as np
import pandas as pd
from plotnine import *
from sklearn import metrics
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# F:\python_software\Anaconda\lib\site-packages\mizani\transforms.py in probability_trans(distribution, *args, **kwargs)
#     557     try:
# --> 558         import scipy.stats as stats
#     559     except ImportError:
#
# F:\python_software\Anaconda\lib\site-packages\scipy\stats\__init__.py in <module>
#     440
# --> 441 from .stats import *
#     442 from .distributions import *
#
# F:\python_software\Anaconda\lib\site-packages\scipy\stats\stats.py in <module>
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#
# F:\python_software\Anaconda\lib\site-packages\scipy\stats\distributions.py in <module>
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#       9
#
# ...
